# %% [markdown]
# # Installation

# %% [markdown]
# ### Installation of Visual Studio Code and MingW in MS Windows
#
# 1. [Video Explanation](https://www.youtube.com/watch?v=oC69vlWofJQ)
# 2. [Download](https://github.com/msys2/msys2-installer/releases/download/2024-01-13/msys2-x86_64-20240113.exe)
# 3. [Official Procedure](https://code.visualstudio.com/docs/cpp/config-mingw)
